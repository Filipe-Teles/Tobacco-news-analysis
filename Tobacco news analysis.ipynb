# %%
import pandas as pd

# %%
# Creating a DataFrame

df = pd.DataFrame()
print(df)

# strings list
df = pd.DataFrame(columns=['File Name', 
        'Federação de Grossistas de Tabaco', 
        'Associação de Hotelaria Restaurantes e Similares', 
        'Associação Nacional de Discotecas', 
        'Pro.Var',
        'Associação Portuguesa de Armazenistas de Tabaco',
        'Tabaqueira',
        'Associação Portuguesa de Bares e Discotecas',
        'Associação Nacional de Revendedores de Combustíveis',
        'Total'
                        
       ])
# Adding file names(news files) and mentions
df.loc[0, 'File Name'] = '38596404_3_3119_mediamonitor.pdf'
df.loc[0, 'Federação de Grossistas de Tabaco'] = 1
df.loc[1, 'File Name'] = '38641421_3_3128_mediamonitor.pdf'
df.loc[1, 'Federação de Grossistas de Tabaco'] = 1
df.loc[2, 'File Name'] = '38595701_3_1106_mediamonitor.pdf'
df.loc[2, 'Associação de Hotelaria Restaurantes e Similares'] = 1
df.loc[3, 'File Name'] = '38997203_3_3116_mediamonitor.pdf'
df.loc[3, 'Associação de Hotelaria Restaurantes e Similares'] = 14
df.loc[4, 'File Name'] = '38595508_3_3119_mediamonitor.pdf'
df.loc[4, 'Associação Nacional de Discotecas'] = 1
df.loc[2, 'Associação Nacional de Discotecas'] = 1
df.loc[5, 'File Name'] = '38586486_3_3128_mediamonitor.pdf'
df.loc[4, 'Pro.Var'] = 1
df.loc[2, 'Pro.Var'] = 1
df.loc[2, 'Associação Portuguesa de Armazenistas de Tabaco'] = 1
df.loc[0, 'Tabaqueira'] = 8
df.loc[1, 'Tabaqueira'] = 1
df.loc[1, 'Tabaqueira'] = 2
df.loc[2, 'Tabaqueira'] = 1
df.loc[6, 'File Name'] = 'Lei do tabaco_Expresso_09-06-2023.pdf'
df.loc[6, 'Tabaqueira'] = 2
df.loc[2, 'Associação Portuguesa de Bares e Discotecas'] = 1
df.loc[2, 'Associação Nacional de Revendedores de Combustíveis'] = 1
df.loc[7, 'File Name'] = 'Total'

# Total of each column
df.loc[7, 'Federação de Grossistas de Tabaco'] = 2
df.loc[7, 'Associação de Hotelaria Restaurantes e Similares'] = 15
df.loc[7, 'Associação Nacional de Discotecas'] = 2
df.loc[7, 'Pro.Var'] = 2
df.loc[7, 'Tabaqueira'] = 13
df.loc[7, 'Associação Portuguesa de Bares e Discotecas'] = 1
df.loc[7, 'Associação Nacional de Revendedores de Combustíveis'] = 1
df.loc[7, 'Total'] = 36
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#                                File Name Federação de Grossistas de Tabaco  \
# 0       38596404_3_3119_mediamonitor.pdf                                 1
# 1       38641421_3_3128_mediamonitor.pdf                                 1
# 2       38595701_3_1106_mediamonitor.pdf                               NaN
# 3       38997203_3_3116_mediamonitor.pdf                               NaN
# 4       38595508_3_3119_mediamonitor.pdf                               NaN
# 5       38586486_3_3128_mediamonitor.pdf                               NaN
# 6  Lei do tabaco_Expresso_09-06-2023.pdf                               NaN
# 7                                  Total                                 2
#
#   Associação de Hotelaria Restaurantes e Similares  \
# 0                                              NaN
# 1                                              NaN
# 2                                                1
# ...

# %%
# Creating a DataFrame - mentions per piece

df = pd.DataFrame()
print(df)

# strings list
df = pd.DataFrame(columns=['File Name', 
        'Margarida Tavares', 
        'Manuel Pizarro', 
        'Sociedade Portuguesa da Pulmonologia', 
        'Total'
                        
       ])
# Adding file names(news files) and mentions
df.loc[0, 'File Name'] = '38586486_3_3128_mediamonitor.pdf'
df.loc[0, 'Margarida Tavares'] = 1
df.loc[1, 'File Name'] = '38641421_3_3128_mediamonitor.pdf'
df.loc[1, 'Margarida Tavares'] = 1
df.loc[2, 'File Name'] = '39547117_3_3128_mediamonitor.pdf'
df.loc[2, 'Margarida Tavares'] = 1
df.loc[3, 'File Name'] = '39548017_3_3128_mediamonitor.pdf'
df.loc[3, 'Margarida Tavares'] = 1
df.loc[4, 'File Name'] = '39556241_3_3119_mediamonitor.pdf'
df.loc[4, 'Margarida Tavares'] = 1
df.loc[5, 'File Name'] = '38595701_3_1106_mediamonitor.pdf'
df.loc[5, 'Manuel Pizarro'] = 1
df.loc[6, 'File Name'] ='38596404_3_3119_mediamonitor.pdf'
df.loc[6, 'Manuel Pizarro'] = 1
df.loc[7, 'File Name'] = '38641421_3_3128_mediamonitor.pdf'
df.loc[7, 'Manuel Pizarro'] = 1
df.loc[8, 'File Name'] = '38649653_3_3128_mediamonitor.pdf'
df.loc[8, 'Manuel Pizarro'] = 1
df.loc[9, 'File Name'] = '39538857_3_3119_mediamonitor.pdf'
df.loc[9, 'Manuel Pizarro'] = 1
df.loc[10,'File Name'] = '39539198_3_3117_mediamonitor.pdf'
df.loc[10, 'Manuel Pizarro'] = 1
df.loc[11, 'File Name'] = '38732076_3_3131_mediamonitor.pdf'
df.loc[11, 'Sociedade Portuguesa da Pulmonologia'] = 1
df.loc[12, 'File Name'] = 'Lei do tabaco_Expresso_09-06-2023.pdf'
df.loc[12, 'Sociedade Portuguesa da Pulmonologia'] = 1
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#                                 File Name Margarida Tavares Manuel Pizarro  \
# 0        38586486_3_3128_mediamonitor.pdf                 1            NaN
# 1        38641421_3_3128_mediamonitor.pdf                 1            NaN
# 2        39547117_3_3128_mediamonitor.pdf                 1            NaN
# 3        39548017_3_3128_mediamonitor.pdf                 1            NaN
# 4        39556241_3_3119_mediamonitor.pdf                 1            NaN
# 5        38595701_3_1106_mediamonitor.pdf               NaN              1
# 6        38596404_3_3119_mediamonitor.pdf               NaN              1
# 7        38641421_3_3128_mediamonitor.pdf               NaN              1
# 8        38649653_3_3128_mediamonitor.pdf               NaN              1
# 9        39538857_3_3119_mediamonitor.pdf               NaN              1
# 10       39539198_3_3117_mediamonitor.pdf               NaN              1
# ...
